# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, accuracy_score
import matplotlib.pyplot as plt
import pickle

# %%
data = pd.read_csv('Salary_dataset.csv', index_col=0)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x="YearsExperience", y="Salary")
plt.title("Salary vs Experience")
plt.show()

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
data = pd.read_csv('Salary_dataset.csv', index_col=0)
plt.figure(figsize=(8, 6))
sns.regplot(data=data, x="YearsExperience", y="Salary", scatter_kws={'s': 50}, line_kws={'color': 'red', 'lw': 2})

plt.title("Salary vs Experience")
plt.show()

# %%
X = data[['YearsExperience']] 
y = data['Salary']  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the results
print(f"Intercept: {model.intercept_}")
print(f"Coefficient: {model.coef_[0]}")
print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Intercept: 21520.590293453723
# Coefficient: 10553.016365688487
# Mean Squared Error: 51726586.16681814
# R^2 Score: 0.938185354479677

# %%
val = np.array([[2.1]])
model.predict(val)
# Out:
# /home/mobcoder/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([43681.9246614])

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)
# Load model
# with open('model.pkl', 'rb') as f:
#     loaded_model = pickle.load(f)
